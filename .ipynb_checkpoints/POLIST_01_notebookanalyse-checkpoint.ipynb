# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import time
import datetime
import math
import gmplot 
from IPython.display import IFrame
import warnings
warnings.filterwarnings('ignore')

# %%
df_list = {'Customer' : pd.read_csv("olist_customers_dataset.csv"),
       'Geoloc' : pd.read_csv("olist_geolocation_dataset.csv"),
       'Items' : pd.read_csv("olist_order_items_dataset.csv"),
       'Payment' : pd.read_csv("olist_order_payments_dataset.csv"),
       'Review' : pd.read_csv("olist_order_reviews_dataset.csv") ,
       'Order' : pd.read_csv("olist_orders_dataset.csv"),
       'Product' : pd.read_csv("olist_products_dataset.csv"),
       'Sellers' : pd.read_csv("olist_sellers_dataset.csv"),
       'Category' : pd.read_csv("product_category_name_translation.csv") 
      }

# %%
for name, df in df_list.items():
    display(name, df.head())
# Out:
# 'Customer'
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
# 'Geoloc'
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP
# 'Items'
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14
# 'Payment'
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45
# 'Review'
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53
# 'Order'
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00
# 'Product'
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0
# 'Sellers'
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP
# 'Category'
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
for name, df in df_list.items():
    display("La table {} contient : {}".format(name, df.shape))
# Out:
# 'La table Customer contient : (99441, 5)'
# 'La table Geoloc contient : (1000163, 5)'
# 'La table Items contient : (112650, 7)'
# 'La table Payment contient : (103886, 5)'
# 'La table Review contient : (100000, 7)'
# 'La table Order contient : (99441, 8)'
# 'La table Product contient : (32951, 9)'
# 'La table Sellers contient : (3095, 4)'
# 'La table Category contient : (71, 2)'

# %%
#Rechercher les clés primaires 
for name, df in df_list.items():
    key = [col for col in df.columns if len(df[col].unique()) == len(df[col])]
    
    if key == []:   
        for col1 in df.columns:
            for col2 in df.columns:
                if col2+" and "+col1 not in key:
                    if len((df[col1].apply(str) + df[col2].apply(str))
                           .unique()) == len(df):
                        key.append(col1+" and "+col2)                                    
    print("Clé(s) primaire(s) de la table {}  : {}".format(name, key))
# Out:
# primary key(s) for Customer table : ['customer_id']
# primary key(s) for Geoloc table : []
# primary key(s) for Items table : ['order_id and order_item_id']
# primary key(s) for Payment table : ['order_id and payment_sequential']
# primary key(s) for Review table : ['review_id and order_id', 'order_id and review_answer_timestamp']
# primary key(s) for Order table : ['order_id', 'customer_id']
# primary key(s) for Product table : ['product_id']
# primary key(s) for Sellers table : ['seller_id']
# primary key(s) for Category table : ['product_category_name', 'product_category_name_english']

# %%
df = pd.concat([df for name, df in df_list.items()], ignore_index=True)

# %%
df.shape
# Out:
# (1551698, 45)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1551698 entries, 0 to 1551697
# Data columns (total 45 columns):
#  #   Column                         Non-Null Count    Dtype
# ---  ------                         --------------    -----
#  0   customer_id                    198882 non-null   object
#  1   customer_unique_id             99441 non-null    object
#  2   customer_zip_code_prefix       99441 non-null    float64
#  3   customer_city                  99441 non-null    object
#  4   customer_state                 99441 non-null    object
#  5   geolocation_zip_code_prefix    1000163 non-null  float64
#  6   geolocation_lat                1000163 non-null  float64
#  7   geolocation_lng                1000163 non-null  float64
#  8   geolocation_city               1000163 non-null  object
#  9   geolocation_state              1000163 non-null  object
#  10  order_id                       415977 non-null   object
#  11  order_item_id                  112650 non-null   float64
#  12  product_id                     145601 non-null   object
#  13  seller_id                      115745 non-null   object
#  14  shipping_limit_date            112650 non-null   object
#  15  price                          112650 non-null   float64
#  16  freight_value                  112650 non-null   float64
#  17  payment_sequential             103886 non-null   float64
#  18  payment_type                   103886 non-null   object
#  19  payment_installments           103886 non-null   float64
#  20  payment_value                  103886 non-null   float64
#  21  review_id                      100000 non-null   object
#  22  review_score                   100000 non-null   float64
#  23  review_comment_title           11715 non-null    object
#  24  review_comment_message         41753 non-null    object
#  25  review_creation_date           100000 non-null   object
#  26  review_answer_timestamp        100000 non-null   object
#  27  order_status                   99441 non-null    object
#  28  order_purchase_timestamp       99441 non-null    object
#  29  order_approved_at              99281 non-null    object
#  30  order_delivered_carrier_date   97658 non-null    object
#  31  order_delivered_customer_date  96476 non-null    object
#  32  order_estimated_delivery_date  99441 non-null    object
#  33  product_category_name          32412 non-null    object
#  34  product_name_lenght            32341 non-null    float64
#  35  product_description_lenght     32341 non-null    float64
#  36  product_photos_qty             32341 non-null    float64
#  37  product_weight_g               32949 non-null    float64
#  38  product_length_cm              32949 non-null    float64
#  39  product_height_cm              32949 non-null    float64
#  40  product_width_cm               32949 non-null    float64
#  41  seller_zip_code_prefix         3095 non-null     float64
#  42  seller_city                    3095 non-null     object
#  43  seller_state                   3095 non-null     object
#  44  product_category_name_english  71 non-null       object
# dtypes: float64(19), object(26)
# memory usage: 532.7+ MB

# %%
df.describe()
# Out:
#        customer_zip_code_prefix  geolocation_zip_code_prefix  geolocation_lat  \
# count              99441.000000                 1.000163e+06     1.000163e+06
# mean               35137.474583                 3.657417e+04    -2.117615e+01
# std                29797.938996                 3.054934e+04     5.715866e+00
# min                 1003.000000                 1.001000e+03    -3.660537e+01
# 25%                11347.000000                 1.107500e+04    -2.360355e+01
# 50%                24416.000000                 2.653000e+04    -2.291938e+01
# 75%                58900.000000                 6.350400e+04    -1.997962e+01
# max                99990.000000                 9.999000e+04     4.506593e+01
#
#        geolocation_lng  order_item_id          price  freight_value  \
# count     1.000163e+06  112650.000000  112650.000000  112650.000000
# mean     -4.639054e+01       1.197834     120.653739      19.990320
# std       4.269748e+00       0.705124     183.633928      15.806405
# min      -1.014668e+02       1.000000       0.850000       0.000000
# 25%      -4.857317e+01       1.000000      39.900000      13.080000
# 50%      -4.663788e+01       1.000000      74.990000      16.260000
# 75%      -4.376771e+01       1.000000     134.900000      21.150000
# max       1.211054e+02      21.000000    6735.000000     409.680000
#
#        payment_sequential  payment_installments  payment_value   review_score  \
# count       103886.000000         103886.000000  103886.000000  100000.000000
# mean             1.092679              2.853349     154.100380       4.070890
# std              0.706584              2.687051     217.494064       1.359663
# min              1.000000              0.000000       0.000000       1.000000
# 25%              1.000000              1.000000      56.790000       4.000000
# 50%              1.000000              1.000000     100.000000       5.000000
# 75%              1.000000              4.000000     171.837500       5.000000
# max             29.000000             24.000000   13664.080000       5.000000
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1900.000000          38.000000          21.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm  seller_zip_code_prefix
# count      32949.000000             3095.000000
# mean          23.196728            32291.059451
# std           12.079047            32713.453830
# min            6.000000             1001.000000
# 25%           15.000000             7093.500000
# 50%           20.000000            14940.000000
# 75%           30.000000            64552.500000
# max          118.000000            99730.000000

# %%
df.tail(10)
# Out:
#         customer_id customer_unique_id  customer_zip_code_prefix  \
# 1551688         NaN                NaN                       NaN
# 1551689         NaN                NaN                       NaN
# 1551690         NaN                NaN                       NaN
# 1551691         NaN                NaN                       NaN
# 1551692         NaN                NaN                       NaN
# 1551693         NaN                NaN                       NaN
# 1551694         NaN                NaN                       NaN
# 1551695         NaN                NaN                       NaN
# 1551696         NaN                NaN                       NaN
# 1551697         NaN                NaN                       NaN
#
#         customer_city customer_state  geolocation_zip_code_prefix  \
# 1551688           NaN            NaN                          NaN
# 1551689           NaN            NaN                          NaN
# 1551690           NaN            NaN                          NaN
# 1551691           NaN            NaN                          NaN
# 1551692           NaN            NaN                          NaN
# 1551693           NaN            NaN                          NaN
# 1551694           NaN            NaN                          NaN
# 1551695           NaN            NaN                          NaN
# 1551696           NaN            NaN                          NaN
# 1551697           NaN            NaN                          NaN
#
#          geolocation_lat  geolocation_lng geolocation_city geolocation_state  \
# 1551688              NaN              NaN              NaN               NaN
# 1551689              NaN              NaN              NaN               NaN
# 1551690              NaN              NaN              NaN               NaN
# 1551691              NaN              NaN              NaN               NaN
# 1551692              NaN              NaN              NaN               NaN
# 1551693              NaN              NaN              NaN               NaN
# 1551694              NaN              NaN              NaN               NaN
# 1551695              NaN              NaN              NaN               NaN
# 1551696              NaN              NaN              NaN               NaN
# 1551697              NaN              NaN              NaN               NaN
#
#          ... product_description_lenght  product_photos_qty product_weight_g  \
# 1551688  ...                        NaN                 NaN              NaN
# 1551689  ...                        NaN                 NaN              NaN
# 1551690  ...                        NaN                 NaN              NaN
# 1551691  ...                        NaN                 NaN              NaN
# 1551692  ...                        NaN                 NaN              NaN
# 1551693  ...                        NaN                 NaN              NaN
# 1551694  ...                        NaN                 NaN              NaN
# 1551695  ...                        NaN                 NaN              NaN
# 1551696  ...                        NaN                 NaN              NaN
# 1551697  ...                        NaN                 NaN              NaN
#
#         product_length_cm product_height_cm  product_width_cm  \
# 1551688               NaN               NaN               NaN
# 1551689               NaN               NaN               NaN
# 1551690               NaN               NaN               NaN
# 1551691               NaN               NaN               NaN
# 1551692               NaN               NaN               NaN
# 1551693               NaN               NaN               NaN
# 1551694               NaN               NaN               NaN
# 1551695               NaN               NaN               NaN
# 1551696               NaN               NaN               NaN
# 1551697               NaN               NaN               NaN
#
#          seller_zip_code_prefix  seller_city seller_state  \
# 1551688                     NaN          NaN          NaN
# 1551689                     NaN          NaN          NaN
# 1551690                     NaN          NaN          NaN
# 1551691                     NaN          NaN          NaN
# 1551692                     NaN          NaN          NaN
# 1551693                     NaN          NaN          NaN
# 1551694                     NaN          NaN          NaN
# 1551695                     NaN          NaN          NaN
# 1551696                     NaN          NaN          NaN
# 1551697                     NaN          NaN          NaN
#
#                  product_category_name_english
# 1551688                                  music
# 1551689                         home_comfort_2
# 1551690  small_appliances_home_oven_and_coffee
# 1551691                      cds_dvds_musicals
# 1551692                           dvds_blu_ray
# 1551693                                flowers
# 1551694                  arts_and_craftmanship
# 1551695                    diapers_and_hygiene
# 1551696              fashion_childrens_clothes
# 1551697                  security_and_services
#
# [10 rows x 45 columns]

# %% [markdown]
# # Début de programme

# %% [markdown]
# ### Table Clients

# %%
customers = pd.read_csv(
    'olist_customers_dataset.csv', sep=',')

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %% [markdown]
# ### Géolocation

# %%
geolocation = pd.read_csv(
    'olist_geolocation_dataset.csv', sep=',')
geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
geolocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
# La table Geolocation compte plus d'un million de lignes et pas de valeurs nulles. 
# Cette table est liée à la table clients grâce à la clé geolocation_zip_code_prefix. 
# Regardons la description du fichier pour avoir un aperçu des étendues de Latitudes et Longitudes:

# %% [markdown]
# ### Entête de commande

# %%
orders = pd.read_csv('olist_orders_dataset.csv', sep=',')
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
# Cette table regroupe les entêtes de commandes, identifiées par un order_id unique 
# et rattaché à un client par le customer_id

# %% [markdown]
# ### Les lignes de commande

# %%
order_items = pd.read_csv(
    'olist_order_items_dataset.csv', sep=',')
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %% [markdown]
# ### Paiement des commandes

# %%
order_payments = pd.read_csv(
    'olist_order_payments_dataset.csv', sep=',')
order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %% [markdown]
# ### Commentaires sur les commandes

# %%
order_reviews= pd.read_csv(
    'olist_order_reviews_dataset.csv', sep=',')
order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
order_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   review_id                100000 non-null  object
#  1   order_id                 100000 non-null  object
#  2   review_score             100000 non-null  int64
#  3   review_comment_title     11715 non-null   object
#  4   review_comment_message   41753 non-null   object
#  5   review_creation_date     100000 non-null  object
#  6   review_answer_timestamp  100000 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %% [markdown]
# ### Table Produit

# %%
products = pd.read_csv(
    'olist_products_dataset.csv', sep=',')
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# ### Table Vendeur ou Boutiquier

# %%
sellers = pd.read_csv('olist_sellers_dataset.csv', sep=',')
sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %% [markdown]
# ### Table catégorie des produits

# %%
category = pd.read_csv(
    'product_category_name_translation.csv', sep=',')
category.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %% [markdown]
# ## Fusion des tables

# %% [markdown]
# ### Jointure des tables Produit et Catégorie

# %%
products_cat = pd.merge(products, category,
                    how="left",
                    on="product_category_name")

del_features_list = ["product_category_name", "product_weight_g",
                     "product_length_cm", "product_height_cm",
                     "product_width_cm"]
products_cat.drop(del_features_list, axis=1, inplace=True)
products_cat = products_cat.rename(columns={"product_category_name_english":
                                    "product_category_name"})
products_cat.head()
# Out:
#                          product_id  product_name_lenght  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5                 40.0
# 1  3aa071139cb16b67ca9e5dea641aaa2f                 44.0
# 2  96bd76ec8810374ed1b65e291975717f                 46.0
# 3  cef67bcfe19066a932b7673e239eb23d                 27.0
# 4  9dc1a7de274444849c219cff195d0b71                 37.0
#
#    product_description_lenght  product_photos_qty product_category_name
# 0                       287.0                 1.0             perfumery
# 1                       276.0                 1.0                   art
# 2                       250.0                 1.0        sports_leisure
# 3                       261.0                 1.0                  baby
# 4                       402.0                 4.0            housewares

# %%
# Plot categories count in dataset
sns.set_style("whitegrid")
font_title = {"family": "serif",
              "color":  "#24445C",
              "weight": "bold",
              "size": 18}

fig = plt.figure(figsize=(18, 8))
sns.countplot(data=products_cat, x="product_category_name",
              edgecolor="black",
              color="#17657D", alpha=0.5)
plt.xticks(range(0, products_cat["product_category_name"].nunique()+1),
           products_cat["product_category_name"].unique(),
           rotation=90)
plt.title(f"Nombre de produits par catégorie \n",fontdict=font_title)
plt.xlabel(f"Catégories de produits")
plt.ylabel(f"Nombre de produits")
# Out:
# Text(0, 0.5, 'Nombre de produits')

# %% [markdown]
# ### Jointure de entêtes et les lignes de commande

# %%
orders_table = pd.merge(order_items, orders,
                       how="left",
                       on="order_id")

del_features_list = ["seller_id", "shipping_limit_date",
                     "order_approved_at",
                     "order_delivered_carrier_date",
                     "order_estimated_delivery_date"]
orders_table.drop(del_features_list,
                 axis=1,
                 inplace=True)
orders_table.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id   price  freight_value  \
# 0  4244733e06e7ecb4970a6e2683c13e61   58.90          13.29
# 1  e5f2d52b802189ee658865ca93d83a8f  239.90          19.93
# 2  c777355d18b72b67abbeef9df44fd0fd  199.00          17.87
# 3  7634da152a4610f1595efa32f14722fc   12.99          12.79
# 4  ac6c3623068f30de03045865e4e10089  199.90          18.14
#
#                         customer_id order_status order_purchase_timestamp  \
# 0  3ce436f183e68e07877b285a838db11a    delivered      2017-09-13 08:59:02
# 1  f6dd3ec061db4e3987629fe6b26e5cce    delivered      2017-04-26 10:53:06
# 2  6489ae5e4333f3693df5ad4372dab6d3    delivered      2018-01-14 14:33:31
# 3  d4eb9395c8c0431ee92fce09860c5a06    delivered      2018-08-08 10:00:35
# 4  58dbd0b2d70206bf40e62cd34e84d795    delivered      2017-02-04 13:57:51
#
#   order_delivered_customer_date
# 0           2017-09-20 23:43:48
# 1           2017-05-12 16:04:24
# 2           2018-01-22 13:19:16
# 3           2018-08-14 13:32:39
# 4           2017-03-01 16:42:31

# %%
orders_table["order_status"].value_counts(normalize=True)
# Out:
# delivered      0.978225
# shipped        0.010519
# canceled       0.004811
# invoiced       0.003187
# processing     0.003169
# unavailable    0.000062
# approved       0.000027
# Name: order_status, dtype: float64

# %%
### Nous gardons les commandes déjà finalisée (livrée)
### Non seulement elles sont les plus pertinentes, mais aussi elles sont largement plus importantes

# %%
orders_table = orders_table[orders_table["order_status"] == "delivered"]

# %%
orders_per_days = orders_table.groupby(orders_table["order_purchase_timestamp"].astype(
    'datetime64[ns]').dt.date).count()["order_id"]
fig = plt.figure(figsize=(20, 8))
ax = orders_per_days.plot(color="#17657D")
ax.set_ylabel("count")
plt.title(f"Evolution du nombre de commandes journalières\n",
          fontdict=font_title)
plt.xlabel(f"Date de la commande")
plt.ylabel(f"Nombre de commandes")
plt.show()

# %%
### Formattage des dates

# %%
datetime_cols = ["order_purchase_timestamp", "order_delivered_customer_date"]
for col in datetime_cols:
    orders_table[col] = orders_table[col].astype('datetime64[ns]')
orders_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112650 entries, 0 to 112649
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112650 non-null  object
#  1   order_item_id                  112650 non-null  int64
#  2   product_id                     112650 non-null  object
#  3   price                          112650 non-null  float64
#  4   freight_value                  112650 non-null  float64
#  5   customer_id                    112650 non-null  object
#  6   order_status                   112650 non-null  object
#  7   order_purchase_timestamp       112650 non-null  datetime64[ns]
#  8   order_delivered_customer_date  110196 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(1), object(4)
# memory usage: 8.6+ MB

# %%
orders_table.groupby(orders_table['order_purchase_timestamp'].dt.month).agg({"order_id": "nunique"}).plot(
    figsize=(12, 8), kind="bar",
    title="Répartition des commandes par mois",
    color="#17657D",
    legend = False
)
plt.xticks(np.arange(0, 12), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
                              'Jul', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec'],
           rotation='horizontal')
plt.xlabel(f"Mois")
plt.ylabel(f"Nombre de commandes")
plt.show()

# %% [markdown]
# ### Repartition des commandes par jour de la semaine

# %%
orders_table.groupby(orders_table['order_purchase_timestamp'].dt.dayofweek)\
    .agg({"order_id": "nunique"})\
    .plot(figsize=(12,8), kind="bar",
          title="Répartition des commandes par jour de la semaine",
          color="#17657D",
          legend=False)
plt.xticks(np.arange(0,7), ['Mon','Tue','Wed','Thu','Fri','Sat','Sun'], rotation='horizontal')
plt.xlabel(f"Jour de la semaine")
plt.ylabel(f"Nombre de commandes")
plt.show()

# %%
orders_table.groupby(orders_table['order_purchase_timestamp'].dt.hour)\
    .agg({"order_id": "nunique"})\
    .plot(figsize=(12,8), kind="bar",
          title="Répartition des commandes par heure de la journée",
          color="#17657D",
          legend=False)
plt.xlabel(f"Heure de la journée")
plt.ylabel(f"Nombre de commandes")
plt.show()

# %%
group_payments = order_payments.groupby(by="order_id").agg(
    {"payment_sequential": 'count',
     "payment_installments": 'sum'})

orders_table = pd.merge(orders_table, group_payments,
                       how="left",
                       on="order_id")
orders_table = orders_table.rename(columns={
    "payment_sequential": "nb_payment_sequential",
    "payment_installments": "sum_payment_installments"})
orders_table.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id   price  freight_value  \
# 0  4244733e06e7ecb4970a6e2683c13e61   58.90          13.29
# 1  e5f2d52b802189ee658865ca93d83a8f  239.90          19.93
# 2  c777355d18b72b67abbeef9df44fd0fd  199.00          17.87
# 3  7634da152a4610f1595efa32f14722fc   12.99          12.79
# 4  ac6c3623068f30de03045865e4e10089  199.90          18.14
#
#                         customer_id order_status order_purchase_timestamp  \
# 0  3ce436f183e68e07877b285a838db11a    delivered      2017-09-13 08:59:02
# 1  f6dd3ec061db4e3987629fe6b26e5cce    delivered      2017-04-26 10:53:06
# 2  6489ae5e4333f3693df5ad4372dab6d3    delivered      2018-01-14 14:33:31
# 3  d4eb9395c8c0431ee92fce09860c5a06    delivered      2018-08-08 10:00:35
# 4  58dbd0b2d70206bf40e62cd34e84d795    delivered      2017-02-04 13:57:51
#
#   order_delivered_customer_date  nb_payment_sequential  \
# 0           2017-09-20 23:43:48                    1.0
# 1           2017-05-12 16:04:24                    1.0
# 2           2018-01-22 13:19:16                    1.0
# 3           2018-08-14 13:32:39                    1.0
# 4           2017-03-01 16:42:31                    1.0
#
#    sum_payment_installments  nb_payment_sequential  sum_payment_installments
# 0                       2.0                    1.0                       2.0
# 1                       3.0                    1.0                       3.0
# 2                       5.0                    1.0                       5.0
# 3                       2.0                    1.0                       2.0
# 4                       3.0                    1.0                       3.0

# %%
fig = plt.figure(figsize=(12, 8))
sns.countplot(data=order_payments, x="payment_type",
              edgecolor="black",
              color="#00d994", alpha=0.7)
plt.title(f"Les moyens de paiement utilisés sur le site",
          fontdict=font_title)
plt.show()
